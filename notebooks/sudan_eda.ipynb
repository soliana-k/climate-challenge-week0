# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from scipy import stats
# %load_ext autoreload
# %autoreload 2
from src.data_processor import Country_Eda

# %%
sudan=Country_Eda('sudan')
sudan.run()
# Out:
# _____ Data Loaded Successfully________
#
#
# _________Specific country set________
#
#
# ________date parsed successfully & month extracted succesfully______
#
#
# --------------Data Quality Report for Sudan-----------
#
# --- Data Information ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 4108 entries, 0 to 4107
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         4108 non-null   int64
#  1   DOY          4108 non-null   int64
#  2   T2M          4108 non-null   float64
#  3   T2M_MAX      4108 non-null   float64
#  4   T2M_MIN      4108 non-null   float64
#  5   T2M_RANGE    4108 non-null   float64
#  6   PRECTOTCORR  4108 non-null   float64
#  7   RH2M         4108 non-null   float64
#  8   WS2M         4108 non-null   float64
#  9   WS2M_MAX     4108 non-null   float64
#  10  PS           4108 non-null   float64
#  11  QV2M         4108 non-null   float64
#  12  COUNTRY      4108 non-null   str
#  13  DATE         4108 non-null   datetime64[us]
#  14  MONTH        4108 non-null   int32
# dtypes: datetime64[us](1), float64(10), int32(1), int64(2), str(1)
# memory usage: 465.5 KB
# None
# Duplicates: no duplicates found
# Replaced all -999 occurrences with NaN.
#
# -------------- missing data check ---------------
#
# no missing values detected.
# all columns have < 5% missing data. good for analysis.
#
# --- Summary Statistics ---
#
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759007    36.773914    21.508510
# min    2015.000000     1.000000    13.180000    21.040000     5.930000
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.681305     4.400065     5.091142
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.643875    31.359192     3.484253     5.157378
# min       3.420000     0.000000     4.690000     0.610000     1.030000
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000    66.490000    87.160000     7.150000     9.050000
# std       3.298919     3.057672    17.851849     1.040667     1.280238
#
#                 PS         QV2M                 DATE        MONTH
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     96.346273     7.864557  2020-08-15 12:00:00     6.423564
# min      95.660000     1.160000  2015-01-01 00:00:00     1.000000
# 25%      96.160000     3.730000  2017-10-23 18:00:00     3.000000
# 50%      96.310000     5.895000  2020-08-15 12:00:00     6.000000
# 75%      96.510000    12.500000  2023-06-08 06:00:00     9.000000
# max      97.310000    19.440000  2026-03-31 00:00:00    12.000000
# std       0.266927     4.880934                  NaN     3.477046
# -------------------------------------------------
#
#
# ------------ Outliers Report-------------------
#
# total rows flagged as outliers 84 and the percentage is 2.044790652385589%
#
# REASONING: Natural Variability: 2.04% outliers is expected in climate data representing extreme weather events (storms/heatwaves). Decision: RETAIN for analysis.
#
# ------------- Missing Value Handling---------------
# applied ffill to remaining missing weather variables.
# -------------------------------------------------
#
# ________Preparing resampled Monthly data for T2M________
# --- Automated Insights for Sudan ---
# 1. TREND: The temperature is generally decreasing (cooling) at a rate of -0.062°C per year.
# 2. VOLATILITY: The total temperature swing across the period is 16.3°C.
#    Note: High seasonal variance detected (likely a high-altitude or inland climate).
# 3. ANOMALY: No significant long-term shift detected between early and late periods.
# ---------------------------------------------------
# c:\Users\Hello\Desktop\kaim\climate-challenge-week0\src\data_processor.py:180: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly, x='MONTH_NAME', y='PRECTOTCORR', ax=ax, palette='Blues_d')
# --- Top 3 Strongest Relationships for Sudan ---
# 1. DOY & MONTH: 1.00 (Strong Positive)
# 2. T2M_MIN & T2M: 0.94 (Strong Positive)
# 3. QV2M & RH2M: 0.94 (Strong Positive)
# -----------------------------------------------------------
#
# _____scatter plot_____
# _____scatter plot 2_____
# The distribution of total daily precipitation is strongly right-skewed. the shape would be long right tail, bulk on the left
# ______exported successfully_______
