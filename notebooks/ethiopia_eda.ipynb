# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from scipy import stats
# %load_ext autoreload
# %autoreload 2
from src.data_processor import Country_Eda
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ethiopia=Country_Eda('ethiopia')
ethiopia.run()
# Out:
# _____ Data Loaded Successfully________
#
#
# _________Specific country set________
#
#
# ________date parsed successfully & month extracted succesfully______
#
#
# -------------- missing data check ---------------
# There is no missing Data
# -------------------------------------------------
#
#
# ------------ Outliers Report-------------------
# REASONING: Natural Variability: 3.21% outliers is expected in climate data representing extreme weather events (storms/heatwaves). Decision: RETAIN for analysis.
#
# total rows flagged as outliers 132 and the percentage is 3.213242453748783%
# -------------------------------------------------
# ________Preparing resampled Monthly data for T2M________
# --- Automated Insights for Ethiopia ---
# 1. TREND: The temperature is generally increasing (warming) at a rate of 0.001°C per year.
# 2. VOLATILITY: The total temperature swing across the period is 7.0°C.
# 3. ANOMALY: No significant long-term shift detected between early and late periods.
# ---------------------------------------------------
# c:\Users\Hello\Desktop\kaim\climate-challenge-week0\src\data_processor.py:152: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly, x='MONTH_NAME', y='PRECTOTCORR', ax=ax, palette='Blues_d')
# --- Top 3 Strongest Relationships for Ethiopia ---
# 1. DOY & MONTH: 1.00 (Strong Positive)
# 2. WS2M & WS2M_MAX: 0.94 (Strong Positive)
# 3. RH2M & QV2M: 0.90 (Strong Positive)
# -----------------------------------------------------------
#
# _____scatter plot_____
# _____scatter plot 2_____
# The distribution of total daily precipitation is strongly right-skewed. the shape would be long right tail, bulk on the left
# c:\Users\Hello\Desktop\kaim\climate-challenge-week0\src\data_processor.py:222: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# ______exported successfully_______
