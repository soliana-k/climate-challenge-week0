# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from scipy import stats
# %load_ext autoreload
# %autoreload 2
from src.data_processor import Country_Eda

# %%
tanzania=Country_Eda('tanzania')
tanzania.run()
# Out:
# _____ Data Loaded Successfully________
#
#
# _________Specific country set________
#
#
# ________date parsed successfully & month extracted succesfully______
#
#
# --------------Data Quality Report for Tanzania-----------
#
# --- Data Information ---
#
# <class 'pandas.DataFrame'>
# RangeIndex: 4108 entries, 0 to 4107
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         4108 non-null   int64
#  1   DOY          4108 non-null   int64
#  2   T2M          4108 non-null   float64
#  3   T2M_MAX      4108 non-null   float64
#  4   T2M_MIN      4108 non-null   float64
#  5   T2M_RANGE    4108 non-null   float64
#  6   PRECTOTCORR  4108 non-null   float64
#  7   RH2M         4108 non-null   float64
#  8   WS2M         4108 non-null   float64
#  9   WS2M_MAX     4108 non-null   float64
#  10  PS           4108 non-null   float64
#  11  QV2M         4108 non-null   float64
#  12  COUNTRY      4108 non-null   str
#  13  DATE         4108 non-null   datetime64[us]
#  14  MONTH        4108 non-null   int32
# dtypes: datetime64[us](1), float64(10), int32(1), int64(2), str(1)
# memory usage: 465.5 KB
# None
# Duplicates: no duplicates found
# Replaced all -999 occurrences with NaN.
#
# -------------- missing data check ---------------
#
# no missing values detected.
# all columns have < 5% missing data. good for analysis.
#
# --- Summary Statistics ---
#
#               YEAR          DOY          T2M      T2M_MAX     T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.00000
# mean   2020.131451   180.121227    26.802422    29.163493    25.03813
# min    2015.000000     1.000000    22.680000    25.410000    20.03000
# 25%    2017.000000    86.000000    25.670000    28.090000    23.71000
# 50%    2020.000000   179.000000    26.990000    29.080000    25.37500
# 75%    2023.000000   272.000000    27.900000    30.170000    26.31000
# max    2026.000000   366.000000    29.970000    33.930000    28.01000
# std       3.248907   106.294767     1.325388     1.371155     1.53544
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean      4.125363     3.740256    77.128038     4.105370     5.189248
# min       0.940000     0.000000    60.060000     1.120000     1.550000
# 25%       3.330000     0.110000    73.167500     3.410000     4.377500
# 50%       4.220000     0.640000    76.585000     4.190000     5.250000
# 75%       4.940000     3.790000    81.100000     4.830000     5.980000
# max       7.590000   122.650000    91.100000     8.400000    11.740000
# std       1.102831     8.003947     5.070501     1.059803     1.215018
#
#                 PS         QV2M                 DATE        MONTH
# count  4108.000000  4108.000000                 4108  4108.000000
# mean    100.801130    16.923683  2020-08-15 12:00:00     6.423564
# min     100.150000    11.380000  2015-01-01 00:00:00     1.000000
# 25%     100.570000    15.340000  2017-10-23 18:00:00     3.000000
# 50%     100.760000    17.220000  2020-08-15 12:00:00     6.000000
# 75%     101.040000    18.420000  2023-06-08 06:00:00     9.000000
# max     101.510000    21.510000  2026-03-31 00:00:00    12.000000
# std       0.284461     1.881741                  NaN     3.477046
# -------------------------------------------------
#
#
# ------------ Outliers Report-------------------
#
# total rows flagged as outliers 97 and the percentage is 2.3612463485881205%
#
# REASONING: Natural Variability: 2.36% outliers is expected in climate data representing extreme weather events (storms/heatwaves). Decision: RETAIN for analysis.
#
# ------------- Missing Value Handling---------------
# applied ffill to remaining missing weather variables.
# -------------------------------------------------
#
# ________Preparing resampled Monthly data for T2M________
# --- Automated Insights for Tanzania ---
# 1. TREND: The temperature is generally increasing (warming) at a rate of 0.016°C per year.
# 2. VOLATILITY: The total temperature swing across the period is 4.7°C.
# 3. ANOMALY: No significant long-term shift detected between early and late periods.
# ---------------------------------------------------
# c:\Users\Hello\Desktop\kaim\climate-challenge-week0\src\data_processor.py:180: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly, x='MONTH_NAME', y='PRECTOTCORR', ax=ax, palette='Blues_d')
# --- Top 3 Strongest Relationships for Tanzania ---
# 1. DOY & MONTH: 1.00 (Strong Positive)
# 2. WS2M & WS2M_MAX: 0.95 (Strong Positive)
# 3. T2M_MIN & T2M: 0.95 (Strong Positive)
# -----------------------------------------------------------
#
# _____scatter plot_____
# _____scatter plot 2_____
# The distribution of total daily precipitation is strongly right-skewed. the shape would be long right tail, bulk on the left
# ______exported successfully_______
